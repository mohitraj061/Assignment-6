# %% [raw]
# Ques 1.) What are escape characters and how do you use them ?
#
# Solution :
#
# Escape characters are special characters that are used to represent certain actions or characters that cannot be easily
# typed or displayed directly in a string. They are typically used in programming languages or when working with text to
# indicate specific formatting or to include characters that have special meanings.
#
# Escape characters are denoted by a backslash () followed by a specific character or sequence of characters. When the
# escape character is encountered in a string, it signals that the following character(s) should be interpreted in a special
# way.
#
# Here are some commonly used escape characters :
#
# 1.) \n : Newline character - it inserts a new line at the point where it appears.
# 2.) \t : Tab character - it inserts a horizontal tab at the point where it appears.
# 3.) " : Double quotation mark - it represents a double quotation mark character within a string that is surrounded by double
#         quotation marks.
# 4.) ' : Single quotation mark - it represents a single quotation mark character within a string that is surrounded by single
#         quotation marks.
#
# Here's an example in Python to demonstrate the usage of escape characters :
#
#
# print("This is a\nmultiline string.")
# print("This is a\ttabbed string.")
# print("He said, \"Hello!\"")
# print('She said, \'Hi!\'')
# print("This is a backslash: \\")
#
# Output :
#
# This is a
# multiline string.
# This is a    tabbed string.
# He said, "Hello!"
# She said, 'Hi!'
# This is a backslash: \
#
# In the example, the escape characters are used to create new lines, tabs and include quotation marks and backslashes within
# the strings. The backslash signals that the following character should be treated differently from its normal interpretation.
#
# Escape characters are a way to include special characters or formatting within strings without causing syntax errors or
# conflicts. They allow programmers to work with a wider range of characters and achieve specific formatting effects when needed.

# %% [raw]
# Ques 2.) What do the escape characters n and t stand for ?
#
# Solution :
#
# The escape character \n stands for a newline character, and the escape character \t stands for a tab character.
#
# Here's a breakdown of each escape character :
#
# 1.) \n : Newline character - When encountered in a string, it creates a new line at that point, causing the text that follows
#          to start on a new line. It is commonly used to create line breaks or separate content into multiple lines.
#
# 2.) \t : Tab character - When encountered in a string, it inserts a horizontal tab or indentation at that point. It is commonly
#          used to align text or create structured output where different elements are visually separated by tabs.
#
# For example, consider the following Python code :
#
# print("First line\nSecond line")
# print("Column 1\tColumn 2\tColumn 3")
#
# Output :
#
# First line
# Second line
# Column 1    Column 2    Column 3
#
# In the first print statement, \n is used to create a new line between "First line" and "Second line," resulting in each string
# being printed on a separate line.
#
# In the second print statement, \t is used to insert tabs between the words "Column 1," "Column 2," and "Column 3," resulting
# in visually aligned columns.
#
# These escape characters are not limited to Python; they are commonly supported in various programming languages and text
# editors as a way to control formatting and layout within strings.

# %% [raw]
# Ques 3.) What is the way to include backslash characters in a string ?
#
# Solution :
#
# To include a backslash character itself in a string, we need to use the escape character \ before the backslash.
# By using \\, we can represent a literal backslash within the string.
#
# Here's an example in Python :
#
# print("This is a backslash: \\")
#
# Output :
#
# This is a backslash: \
#
# In the example, the \\ represents a single backslash character within the string. The first backslash serves as the escape
# character, and the second backslash is the actual backslash character that is printed.
#
# Similarly, in many programming languages and contexts, we use \\ to represent a backslash character within a string.
#
# It's important to note that the usage of the escape character may vary slightly depending on the programming language or the
# specific context in which we are working. Always consult the documentation or language specifications for precise details on
# using escape characters in strings.

# %% [raw]
# Ques 4.) The string "Howl's Moving castle" is a correct value. Why isn't the single quote character in the word Howl's not
#          escaped a problem ?
#
# Solution :
#
# In many programming languages, including Python, the single quote character (') can be included directly within a string that
# is surrounded by double quotation marks ("), without requiring an escape character. Similarly, if the string is surrounded
# by single quotation marks ('), it can contain double quotation marks (") without the need for escaping.
#
# This concept is known as string interpolation or string literal escaping. It allows for more convenient inclusion of quotes
# within a string, reducing the need for escape characters and making the code more readable.
#
# So, in the string "Howl's Moving castle", the single quote within the word "Howl's" does not need to be escaped because the
# entire string is surrounded by double quotation marks. The interpreter/compiler understands that the single quote within the
# string is part of the actual string value and not a delimiter for the start or end of the string.
#
# Here's an example in Python to demonstrate this behavior :
#
# movie_title = "Howl's Moving castle"
# print(movie_title)
#
# Output :
#
# Howl's Moving castle
#
# In this example, the string "Howl's Moving castle" is assigned to the variable movie_title and then printed. The single quote
# within the word "Howl's" is not escaped because it is part of the string value, and the code executes without any issues.
#
# However, if you were using single quotation marks to define the string, like 'Howl's Moving castle', then you would need to
# escape the single quote character with a backslash: 'Howl\'s Moving castle'. This is because the single quote character would
# otherwise be interpreted as the closing delimiter for the string, causing a syntax error.

# %% [raw]
# Ques 5.) How do you write a string of newlines if you don't want to use the n character ?
#
# Solution :
#
# To write a string of newlines without using the \n escape character, we can achieve it by using multi-line string literals,
# specific to the programming language we are using.
#
# In Python, for instance, we can create a multi-line string using triple quotes (''' or """). Within this multi-line string,
# we can include newlines directly without the need for escape characters.
#
# Here's an example :
#
# multiline_string = '''This is a
# multiline string
# without using \n escape character.'''
# print(multiline_string)
#
#
# Output :
#
# This is a
# multiline string
# without using \n escape character.
#
# In the example, the multiline_string variable contains a multi-line string literal that spans multiple lines. The newlines are
# directly included in the string without using the \n escape character. When the string is printed, the newlines are honored,
# resulting in each line being displayed on a separate line.
#
# By using multi-line string literals, we can include newlines and write strings with multiple lines without relying on escape
# characters specifically for newlines. However, keep in mind that this approach is language-dependent, and different programming
# languages may have different syntax and conventions for representing multi-line strings.

# %% [raw]
# Ques 6.) What are the values of the given expressions ?
#          'Hello,world!'[1]
#          'Hello,world!'[0.5]
#          'Hello,world!'[:5]
#          'Hello,world!'[3:]
#
# Solution :
#
# Let's evaluate each of the given expressions:
#
# 1.) 'Hello,world!'[1] : This expression accesses the character at index 1 of the string 'Hello,world!'. In Python and many
#      programming languages, indexing starts from 0. Therefore, the value of this expression is 'e'.
#
# 2.) 'Hello,world!'[0.5] : This expression attempts to access the character at index 0.5 of the string 'Hello,world!'.
#      However, indexing is typically done with integer values, and it does not make sense to use a floating-point number as
#      an index. This expression would result in a TypeError or an invalid index error, depending on the programming language.
#
# 3.) 'Hello,world!'[:5] : This expression retrieves a substring from the beginning of the string up to, but not including,
#      index 5. In Python and many programming languages, the syntax [:5] denotes slicing a string from the start to the
#      specified index. The value of this expression is 'Hello'.
#
# 4.) 'Hello,world!'[3:] : This expression retrieves a substring from index 3 of the string until the end. The syntax [3:]
#      denotes slicing a string from the specified index to the end. The value of this expression is 'lo,world!'.
#
# To summarize:
#
# 'Hello,world!'[1] evaluates to 'e'.
# 'Hello,world!'[0.5] would result in an error (TypeError or invalid index error).
# 'Hello,world!'[:5] evaluates to 'Hello'.
# 'Hello,world!'[3:] evaluates to 'lo,world!'.

# %% [raw]
# ques 7.) What are the values of the following expressions ?
#
#          'Hello'.upper()
#          'Hello'.upper().isupper()
#          'Hello'.upper().lower()
#
# Solution :
#
# Let's evaluate each of the given expressions :
#
# 1.) 'Hello'.upper() : This expression applies the upper() method to the string 'Hello'. The upper() method converts all the
#      characters in the string to uppercase. The value of this expression is 'HELLO'.
#
# 2.) 'Hello'.upper().isupper() : This expression applies the upper() method to the string 'Hello' and then calls the isupper()
#      method on the result. The isupper() method checks if all the characters in the string are uppercase. Since the result of
#     'Hello'.upper() is 'HELLO', which consists of all uppercase characters, the isupper() method returns True. Therefore, the
#      value of this expression is True.
#
# 3.) 'Hello'.upper().lower() : This expression applies the upper() method to the string 'Hello', converting it to 'HELLO'. Then,
#     the lower() method is called on 'HELLO', converting it back to lowercase. The value of this expression is 'hello'.
#
# To summarize :
#
# 'Hello'.upper() evaluates to 'HELLO'.
# 'Hello'.upper().isupper() evaluates to True.
# 'Hello'.upper().lower() evaluates to 'hello'.

# %% [raw]
# Ques 8.) What are the values of the following expressions ?
#
#         'Remember, remember, the fifth of July.'.split()
#         '_'.join('There can only one.'.split())
#
# Solution :
#
# Let's evaluate each of the given expressions :
#
# 1.) 'Remember, remember, the fifth of July.'.split() : This expression applies the split() method to the string
#     'Remember, remember,  the fifth of July.'. The split() method splits the string into a list of substrings based on
#      whitespace (by default). Each substring becomes an element in the resulting list. The value of this expression is
#      ['Remember,', 'remember,', 'the', 'fifth', 'of', 'July.'].
#
# 2.) '_'.join('There can only one.'.split()) : This expression applies the split() method to the string 'There can only one.'.
#     The split() method splits the string into a list of substrings based on whitespace. The resulting list is
#     ['There', 'can', 'only', 'one.']. Then, the join() method is called on the string '_'.join() and the list
#     ['There', 'can', 'only', 'one.']. The join() method concatenates the elements of the list using the specified delimiter,
#     which is '_' in this case. The value of this expression is 'There_can_only_one.'.
#
# To summarize:
#
# * 'Remember, remember, the fifth of July.'.split() evaluates to ['Remember,', 'remember,', 'the', 'fifth', 'of', 'July.'].
#
# * '_'.join('There can only one.'.split()) evaluates to 'There_can_only_one.'

# %% [raw]
# Ques 9.) What are the methods for right-justifying, left-justifying, and centering a string ?
#
# Solution :
#
# To right-justify, left-justify, or center a string, we can use the following methods :
#
# 1.) Right-justifying a string : The rjust() method is used to right-justify a string by adding spaces (or a specified character)
#     on the left side of the string to reach a specified width. The syntax is as follows :
#
#     string.rjust(width, fillchar)
#
# * string : The original string to be right-justified.
# * width : The total width of the resulting justified string, including the original string and any additional characters.
# * fillchar (optional) : The character used to fill the space on the left side. It is an optional parameter, and by default,
#   it is a space (' ').
#
# Example :
#
# text = 'Hello'
# justified_text = text.rjust(10)
# print(justified_text)
#
#
# 2.) Left-justifying a string: The ljust() method is used to left-justify a string by adding spaces (or a specified character)
#     on the right side of the string to reach a specified width.
#     The syntax is as follows :
#
#     string.ljust(width, fillchar)
#
# * string : The original string to be left-justified.
# * width : The total width of the resulting justified string, including the original string and any additional characters.
# * fillchar (optional) : The character used to fill the space on the right side. It is an optional parameter, and by default,
#   it is a space (' ').
#
# Example :
#
# text = 'Hello'
# justified_text = text.ljust(10)
# print(justified_text)
#
#
# 3.) Centering a string: The center() method is used to center a string by adding spaces (or a specified character) on both
#     sides of the string to reach a specified width. The syntax is as follows :
#
#     string.center(width, fillchar)
#
# * string : The original string to be centered.
# * width : The total width of the resulting centered string, including the original string and any additional characters.
# * fillchar (optional) : The character used to fill the space on both sides. It is an optional parameter, and by default, it
#   is a space (' ').
#
# Example :
#
# text = 'Hello'
# centered_text = text.center(10)
# print(centered_text)
#
# These methods allow you to adjust the alignment of a string within a specified width, providing right-justified, left-justified,
# or centered output.

# %% [raw]
# Ques 10.) What is the best way to remove whitespace characters from the start or end ?
#
# Solution :
#
# The best way to remove whitespace characters from the start or end of a string is by using the strip() method. The strip()
# method removes leading and trailing whitespace characters (spaces, tabs, newlines) from a string.
#
# Here's an example in Python :
#
# text = "  Hello, World!  "
# trimmed_text = text.strip()
# print(trimmed_text)
#
# Output :
#
# Hello, World!
#
# In the example, the strip() method is called on the string text. It removes the leading and trailing whitespace characters,
# resulting in the trimmed string "Hello, World!". The trimmed string is then printed.
#
# The strip() method is a convenient and commonly used way to remove whitespace characters from the start or end of a string.
# It is available in various programming languages and provides a concise way to clean up strings by removing leading and
# trailing whitespace.
